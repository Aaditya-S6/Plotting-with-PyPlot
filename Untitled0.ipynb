# %% [markdown]
# <a href="https://colab.research.google.com/github/Aaditya-S6/Plotting-with-PyPlot/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Line Chart using plot() Function

# %%
import matplotlib.pyplot as pl
a=[1,2,3,4]
b=[2,4,6,8]
pl.plot(a,b)

# %%
pl.xlabel("Some Values")
pl.ylabel("Double Values")
pl.plot(a,b)
